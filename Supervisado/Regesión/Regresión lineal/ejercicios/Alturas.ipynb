# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Emplearemos un conjunto de datos sencillo, altura y edad de los alumnos en clase. ¿Podemos derivar uno del otro?
#
# $$
#
# altura = \beta_1 edad + \beta_0
#
# $$

# %%
lista_alumnos = [("Leonardo S", 24, 1.82), 
                 ("Piero T", 25, 1.71), 
                 ("Marta B", 35, 1.66), 
                 ("Silvia P", 37, 1.63), 
                 ("Faro Z", 29, 1.90), 
                 ("Miguel N", 27, 1.80), 
                 ("Alejandro M", 28, 1.70), 
                 ("Cristina M", 32, 1.60), 
                 ("Francisco P", 36, 1.74), 
                 ("Jorge D", 45, 1.72), 
                 ("Jesús L", 41, 1.65), 
                 ("Marta G", 30, 1.65), 
                 ("Jennifer S", 40, 1.60), 
                 ("Diego I", 39, 1.80), 
                 ("Antonio C", 23, 1.77), 
                 ("Juan M", 32, 1.75), 
                 ("David S", 27, 1.70), 
                 ("Antonio J", 34, 1.80), 
                 ("Carlos H", 27, 1.77), 
                 ("Erik U", 28, 1.70), 
                 ("Marcos L", 35, 1.80)]

# %% [markdown]
# # Ejercicio 1.
#
# Obten un dataframe de los datos indicados.

# %%
df_alumnos = pd.DataFrame(lista_alumnos, columns=["Nombre", "Edad", "Altura"])
df_alumnos.head()
# Out:
#        Nombre  Edad  Altura
# 0  Leonardo S    24    1.82
# 1     Piero T    25    1.71
# 2     Marta B    35    1.66
# 3    Silvia P    37    1.63
# 4      Faro Z    29    1.90

# %% [markdown]
# # Ejercicio 2
#
# Realiza una descripción de las distribuciones de las variables.

# %%
df_alumnos.describe()
# Out:
#             Edad     Altura
# count  21.000000  21.000000
# mean   32.095238   1.727143
# std     6.081980   0.079003
# min    23.000000   1.600000
# 25%    27.000000   1.660000
# 50%    32.000000   1.720000
# 75%    36.000000   1.800000
# max    45.000000   1.900000

# %% [markdown]
# # Ejercicio 3
#
# Divide el conjunto de datos en _train_ y _test_

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_alumnos[['Edad']], df_alumnos[['Altura']], test_size = 0.40, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (12, 1)
# (12, 1)
# (9, 1)
# (9, 1)

# %% [markdown]
# # Ejercicio 4
#
# Entrena un modelo de regresión lineal

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.score(X_train, y_train)
# Out:
# 0.06237563602461882

# %% [markdown]
# # Ejercicio 5
#
# Analiza los coeficientes.

# %%
print(lm.intercept_)
# Out:
# [1.82632735]

# %%
print(lm.coef_)
# Out:
# [[-0.00327345]]

# %%
coeff_df = pd.DataFrame(lm.coef_,
                        X.columns,
                        columns=['Coefficient'])
coeff_df
# Out:
#       Coefficient
# Edad    -0.003273

# %%
X_test
# Out:
#     Edad
# 0     24
# 17    34
# 15    32
# 1     25
# 8     36
# 5     27
# 11    30
# 3     37
# 18    27

# %%
predictions = lm.predict(X_test)
predictions
# Out:
# array([[1.74776447],
#        [1.71502994],
#        [1.72157685],
#        [1.74449102],
#        [1.70848303],
#        [1.73794411],
#        [1.72812375],
#        [1.70520958],
#        [1.73794411]])

# %% [markdown]
# # Ejercicio 6
#
# Evalúa visualmente el modelo.

# %%
sns.scatterplot(x = y_test, y = predictions);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sns.scatterplot(x = y_test, y = predictions);
#
# File c:\Users\Nicole Passi\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
sns.displot((y_test - predictions));

# %% [markdown]
# # Ejercicio 7
#
# Obtén las métricas de error relevantes para este modelo.

# %%
# ...
